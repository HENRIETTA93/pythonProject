# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:psql@localhost:5433/final_proj', echo=False)

# %%
engine.execute('select * from "VAERSDATA"').fetchall()
# Out:
# [(918394, '01/04/2021', 'TX', 33.0, 33.0, None, 'F', None, 'fast heart rate after about 20 minutes of the vaccine that lasted an hour; dizziness or feeling of overwhelming for about an hour as well; was able to drive home no problem; very very tired after vaccine; no treatment everything was self-limiting', None, None, None, None, None, None, None, None, 'Y', '12/24/2020', '12/24/2020', '0', None, 'PVT', None, 'Centrum MVI, Caltrate D, Turmeric, Vit D, Vit C, Fish Oil', None, None, None, None, '2', '01/04/2021', None, None, None, None),
#  (918395, '01/04/2021', None, 38.0, 38.0, None, 'F', None, '9 x 9.5 cm redness and felt harder and warmer than surrounding area appear 48 hours after being vaccinated.', None, None, None, None, None, None, None, None, None, '12/27/2020', '12/30/2020', '3', None, 'PVT', None, None, None, None, None, None, '2', '01/04/2021', None, 'Y', None, None),
# ...

# %%
engine.execute("select * from users").fetchall()
# Out:
# [(0, 'User 6'), (1, 'User 7'), (2, None)]

# %%
df=pd.read_sql("select * from users",con=engine)
df
# Out:
#    index    name
# 0      0  User 6
# 1      1  User 7
# 2      2    None

# %%
df['index'].dropna(inplace=False)
# Out:
# 0    0
# 1    1
# 2    2
# Name: index, dtype: int64

# %%
df=df['name'].dropna()

# %%
df
# Out:
# 0    User 6
# 1    User 7
# Name: name, dtype: object

# %%
df[]
# Out:
# 0    User 6
# 1    User 7
# Name: name, dtype: object

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman',None],
                   "toy": [None, 'Batmobile', 'Bullwhip',None],
                   "born": [None, pd.Timestamp("1940-04-25"),
                            pd.NaT,None]})
df
# Out:
#        name        toy       born
# 0    Alfred       None        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3      None       None        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred       None        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
