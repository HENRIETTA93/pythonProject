# %% [markdown]
# # Final Project
#
# Group 4: Jiaqi Bai, Somender Chaudhary, Shreyas Deo, Andrew Levy, Wenqwing Qin, Matias Roca-Guiulfo, and Alexis Yang

# %% [markdown]
# ## Ask 1 - Data Collection (10%)
#
# Use the JHU datasets website, collect the following dataset
# - Cases and Deaths (04/12/2020 – 11/15/2021)
# - Vaccine and People Vaccinated (12/10/2020 – 11/15/2021)
# - Testing
#
# The readme/dictionary files are available for all datasets Cases and Deaths, Vaccine and Testing.
#
# Acquire daily U.S. report. Perform initial exploration to make sure it is suitable for dimensional modeling and analytical analysis.
#
# Expectation: Provide a list of your data sources, The links to the data sources and links to any documentations you used.
#
# Links
# - JHU Datasets: https://coronavirus.jhu.edu/about/how-to-use-our-data
# - Cases: https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports_us
# - Deaths: https://github.com/govex/COVID-19/blob/master/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv & https://raw.githubusercontent.com/govex/COVID-
# - Vaccine: https://github.com/govex/COVID-19/blob/master/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# - People Vaccinated: https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/us_data/time_series/people_vaccinated_us_timeline.csv
# - Testing: https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/testing_data/time_series_covid19_US.csv
# Readme/dictionary files
# - https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/README.md
# - https://github.com/govex/COVID-19/blob/master/data_tables/vaccine_data/us_data/data_dictionary.csv
# - https://github.com/govex/COVID-19/blob/master/data_tables/testing_data/data_dictionary.csv

# %% [markdown]
# #### Collecting Cases and Deaths Dataset

# %%
# !wc -l cases_deaths.csv # printing the number of lines presents in the cases_deaths.csv file
# Out:
# 34471 cases_deaths.csv

# %%
# !head cases_deaths.csv # printing the first 10 lines of the cases_deaths.csv file
# Out:
# Province_State,Country_Region,Last_Update,Lat,Long_,Confirmed,Deaths,Recovered,Active,FIPS,Incident_Rate,Total_Test_Results,People_Hospitalized,Case_Fatality_Ratio,UID,ISO3,Testing_Rate,Hospitalization_Rate
# Alabama,US,2021-01-02 05:30:44,32.3182,-86.9023,365747,4872,202137.0,158738.0,1.0,7459.375895463867,3275341.0,,1.3320683423240656,84000001.0,USA,66800.27369964625,
# Alaska,US,2021-01-02 05:30:44,61.3707,-152.4044,47019,206,7165.0,39615.0,2.0,6422.844801071706,1275750.0,,0.4384284680543141,84000002.0,USA,174391.1857780451,
# American Samoa,US,2021-01-02 05:30:44,-14.271,-170.132,0,0,,0.0,60.0,0.0,2140.0,,,16.0,ASM,3846.084721698028,
# Arizona,US,2021-01-02 05:30:44,33.7298,-111.4312,530267,9015,76934.0,444318.0,4.0,7285.171274003372,5155330.0,,1.7000869373353424,84000004.0,USA,39551.860582022906,
# Arkansas,US,2021-01-02 05:30:44,34.9697,-92.3731,229442,3711,199247.0,26484.0,5.0,7602.945718144717,2051488.0,,1.6174022192972517,84000005.0,USA,67979.49767446793,
# California,US,2021-01-02 05:30:44,36.1162,-119.6816,2437211,26168,,2309915.0,6.0,5912.603297465698,33058311.0,,1.1251600354592777,84000006.0,USA,83666.03670970372,
# Colorado,US,2021-01-02 05:30:44,39.0598,-105.3111,337161,4873,18102.0,314186.0,8.0,5854.774381044729,4444206.0,,1.4453035790023163,84000008.0,USA,77173.28941628858,
# Connecticut,US,2021-01-02 05:30:44,41.5978,-72.7554,185708,5995,9800.0,169913.0,9.0,5208.781228551867,4320693.0,,3.2281861847631768,84000009.0,USA,121187.80339422885,
# Delaware,US,2021-01-02 05:30:44,39.3185,-75.5071,58064,1065,18851.0,38283.0,10.0,5962.841099075341,984606.0,,1.6016809038302562,84000010.0,USA,101113.41146314713,

# %%
# !head -5 cases_deaths.csv | csvlook # rendering the cases_deaths.csv file into a readable format
# Out:
# | Province_State | Country_Region |         Last_Update |      Lat |     Long_ | Confirmed | Deaths | Recovered |  Active | FIPS | Incident_Rate | Total_Test_Results | People_Hospitalized | Case_Fatality_Ratio |        UID | ISO3 | Testing_Rate | Hospitalization_Rate |
# | -------------- | -------------- | ------------------- | -------- | --------- | --------- | ------ | --------- | ------- | ---- | ------------- | ------------------ | ------------------- | ------------------- | ---------- | ---- | ------------ | -------------------- |
# | Alabama        | US             | 2021-01-02 05:30:44 |  32.318… |  -86.902… |   365,747 |  4,872 |   202,137 | 158,738 |    1 |    7,459.376… |          3,275,341 |                     |              1.332… | 84,000,001 | USA  |  66,800.274… |                      |
# | Alaska         | US             | 2021-01-02 05:30:44 |  61.371… | -152.404… |    47,019 |    206 |     7,165 |  39,615 |    2 |    6,422.845… |          1,275,750 |                     |              0.438… | 84,000,002 | USA  | 174,391.186… |                      |
# | American Samoa | US             | 2021-01-02 05:30:44 | -14.271… | -170.132… |         0 |      0 |           |       0 |   60 |        0.000… |              2,140 |                     |                     |         16 | ASM  |   3,846.085… |                      |
# | Arizona        | US             | 2021-01-02 05:30:44 |  33.730… | -111.431… |   530,267 |  9,015 |    76,934 | 444,318 |    4 |    7,285.171… |          5,155,330 |                     |              1.700… | 84,000,004 | USA  |  39,551.861… |                      |

# %%
# !head -n 1000 cases_deaths.csv | csvstat # printing the descriptive statistics for the first 1000 lines of the cases_deaths.csv file
# Out:
#   1. "Province_State"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         58
# 	Longest value:         24 characters
# 	Most common values:    Alabama (18x)
# 	                       Alaska (18x)
# 	                       American Samoa (18x)
# 	                       Arizona (18x)
# 	                       Arkansas (18x)
#
#   2. "Country_Region"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         2 characters
# 	Most common values:    US (999x)
#
#   3. "Last_Update"
#
# 	Type of data:          DateTime
# 	Contains null values:  False
# 	Unique values:         29
# 	Smallest value:        2021-01-02 05:30:44
# 	Largest value:         2021-01-19 09:30:34
# 	Most common values:    2021-01-02 05:30:44 (58x)
# 	                       2021-01-03 05:30:33 (58x)
# 	                       2021-01-04 05:30:45 (58x)
# 	                       2021-01-05 05:30:33 (58x)
# 	                       2021-01-06 05:30:39 (58x)
#
#   4. "Lat"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         57
# 	Smallest value:        -14.271
# 	Largest value:         61.3707
# 	Sum:                   35475.679
# 	Mean:                  36.800497
# 	Median:                39.0598
# 	StDev:                 10.890023
# 	Most common values:    None (35x)
# 	                       32.3182 (18x)
# 	                       61.3707 (18x)
# 	                       -14.271 (18x)
# 	                       33.7298 (18x)
#
#   5. "Long_"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         57
# 	Smallest value:        -170.132
# 	Largest value:         145.6739
# 	Sum:                   -82345.5517
# 	Mean:                  -85.420697
# 	Median:                -87.9442
# 	StDev:                 49.17752
# 	Most common values:    None (35x)
# 	                       -86.9023 (18x)
# 	                       -152.4044 (18x)
# 	                       -170.132 (18x)
# 	                       -111.4312 (18x)
#
#   6. "Confirmed"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         893
# 	Smallest value:        0
# 	Largest value:         3115025
# 	Sum:                   386166188
# 	Mean:                  386552.740741
# 	Median:                261573
# 	StDev:                 493664.93833
# 	Most common values:    0 (18x)
# 	                       49 (18x)
# 	                       103 (17x)
# 	                       128 (7x)
# 	                       122 (5x)
#
#   7. "Deaths"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         802
# 	Smallest value:        0
# 	Largest value:         40809
# 	Sum:                   6535262
# 	Mean:                  6541.803804
# 	Median:                3605
# 	StDev:                 8329.27765
# 	Most common values:    0 (36x)
# 	                       3 (17x)
# 	                       2 (17x)
# 	                       24 (14x)
# 	                       124 (8x)
#
#   8. "Recovered"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         582
# 	Smallest value:        29
# 	Largest value:         1677588
# 	Sum:                   149500426
# 	Mean:                  181212.637576
# 	Median:                78690
# 	StDev:                 262453.746082
# 	Most common values:    None (174x)
# 	                       7165 (18x)
# 	                       9800 (18x)
# 	                       18851 (18x)
# 	                       11958 (17x)
#
#   9. "Active"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         882
# 	Smallest value:        0
# 	Largest value:         2986012
# 	Sum:                   227083508
# 	Mean:                  227310.818819
# 	Median:                74709
# 	StDev:                 431514.87091
# 	Most common values:    0 (18x)
# 	                       49 (18x)
# 	                       100 (17x)
# 	                       97 (7x)
# 	                       129 (6x)
#
#  10. "FIPS"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         58
# 	Smallest value:        1
# 	Largest value:         99999
# 	Sum:                   3331082
# 	Mean:                  3334.416416
# 	Median:                32
# 	StDev:                 17369.90336
# 	Most common values:    1 (18x)
# 	                       2 (18x)
# 	                       60 (18x)
# 	                       4 (18x)
# 	                       5 (18x)
#
#  11. "Incident_Rate"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         889
# 	Smallest value:        0
# 	Largest value:         12579.553895
# 	Sum:                   6187012.037415
# 	Mean:                  6418.062279
# 	Median:                6820.3201
# 	StDev:                 2616.075354
# 	Most common values:    None (35x)
# 	                       0 (18x)
# 	                       232.119542 (7x)
# 	                       221.238938 (5x)
# 	                       226.67924 (5x)
#
#  12. "Total_Test_Results"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         869
# 	Smallest value:        2140
# 	Largest value:         38655756
# 	Sum:                   4754609342
# 	Mean:                  4932167.36722
# 	Median:                2811352.5
# 	StDev:                 6505554.375801
# 	Most common values:    None (35x)
# 	                       2140 (18x)
# 	                       17557 (6x)
# 	                       17551 (5x)
# 	                       17554 (5x)
#
#  13. "People_Hospitalized"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  14. "Case_Fatality_Ratio"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         890
# 	Smallest value:        0
# 	Largest value:         3.968016
# 	Sum:                   1583.223427
# 	Mean:                  1.613887
# 	Median:                1.500545
# 	StDev:                 0.694615
# 	Most common values:    None (18x)
# 	                       0 (18x)
# 	                       2.912621 (17x)
# 	                       1.5625 (7x)
# 	                       1.639344 (5x)
#
#  15. "UID"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         58
# 	Smallest value:        16
# 	Largest value:         84099999
# 	Sum:                   76695365837
# 	Mean:                  76772137.974975
# 	Median:                84000027
# 	StDev:                 23573951.576388
# 	Most common values:    84000001 (18x)
# 	                       84000002 (18x)
# 	                       16 (18x)
# 	                       84000004 (18x)
# 	                       84000005 (18x)
#
#  16. "ISO3"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         6
# 	Longest value:         3 characters
# 	Most common values:    USA (913x)
# 	                       ASM (18x)
# 	                       GUM (17x)
# 	                       MNP (17x)
# 	                       PRI (17x)
#
#  17. "Testing_Rate"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         869
# 	Smallest value:        3846.084722
# 	Largest value:         211664.86212
# 	Sum:                   78804978.800365
# 	Mean:                  81747.90332
# 	Median:                76097.348965
# 	StDev:                 39100.621454
# 	Most common values:    None (35x)
# 	                       3846.084722 (18x)
# 	                       31838.459307 (6x)
# 	                       31827.578703 (5x)
# 	                       31833.019005 (5x)
#
#  18. "Hospitalization_Rate"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
# Row count: 999

# %% [markdown]
# #### Collecting Vaccine Dataset

# %%
# !wget https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Out:
# --2021-11-27 17:37:04--  https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10348810 (9.9M) [text/plain]
# Saving to: ‘vaccine_data_us_timeline.csv’
#
# vaccine_data_us_tim 100%[===================>]   9.87M  --.-KB/s    in 0.09s
#
# 2021-11-27 17:37:04 (109 MB/s) - ‘vaccine_data_us_timeline.csv’ saved [10348810/10348810]

# %%
# !mv vaccine_data_us_timeline.csv vaccine.csv # changing the name of the orginal downloaded csv file into vaccine.csv

# %%
# !wc -l vaccine.csv # printing the number of lines presents in the vaccine.csv file
# Out:
# 116249 vaccine.csv

# %%
# !head vaccine.csv | csvcut -n # printing the first 10 lines of the vaccine.csv file
# Out:
#   1: Province_State
#   2: Date
#   3: Vaccine_Type
#   4: FIPS
#   5: Country_Region
#   6: Lat
#   7: Long_
#   8: Doses_alloc
#   9: Doses_shipped
#  10: Doses_admin
#  11: Stage_One_Doses
#  12: Stage_Two_Doses
#  13: Combined_Key

# %%
# !head -5 vaccine.csv | csvlook # rendering the vaccine.csv file into a readable format
# Out:
# | Province_State |       Date | Vaccine_Type | FIPS | Country_Region |     Lat |    Long_ | Doses_alloc | Doses_shipped | Doses_admin | Stage_One_Doses | Stage_Two_Doses | Combined_Key |
# | -------------- | ---------- | ------------ | ---- | -------------- | ------- | -------- | ----------- | ------------- | ----------- | --------------- | --------------- | ------------ |
# | Alabama        | 2020-12-10 | All          | True | US             | 32.318… | -86.902… |             |               |             |                 |                 | Alabama, US  |
# | Alabama        | 2020-12-10 | Moderna      | True | US             | 32.318… | -86.902… |             |               |             |                 |                 | Alabama, US  |
# | Alabama        | 2020-12-10 | Pfizer       | True | US             | 32.318… | -86.902… |             |               |             |                 |                 | Alabama, US  |
# | Alabama        | 2020-12-11 | All          | True | US             | 32.318… | -86.902… |             |               |             |                 |                 | Alabama, US  |

# %%
# !head -n 1000 vaccine.csv | csvstat # printing the descriptive statistics for the first 1000 lines of the vaccine.csv file
# Out:
#   1. "Province_State"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         7 characters
# 	Most common values:    Alabama (999x)
#
#   2. "Date"
#
# 	Type of data:          Date
# 	Contains null values:  False
# 	Unique values:         198
# 	Smallest value:        2020-12-10
# 	Largest value:         2021-06-25
# 	Most common values:    2021-03-15 (6x)
# 	                       2021-03-16 (6x)
# 	                       2021-03-17 (6x)
# 	                       2021-03-18 (6x)
# 	                       2021-03-19 (6x)
#
#   3. "Vaccine_Type"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         6
# 	Longest value:         10 characters
# 	Most common values:    All (198x)
# 	                       Moderna (198x)
# 	                       Pfizer (198x)
# 	                       Unassigned (194x)
# 	                       Janssen (109x)
#
#   4. "FIPS"
#
# 	Type of data:          Boolean
# 	Contains null values:  False
# 	Unique values:         1
# 	Most common values:    True (999x)
#
#   5. "Country_Region"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         2 characters
# 	Most common values:    US (999x)
#
#   6. "Lat"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1
# 	Smallest value:        32.3182
# 	Largest value:         32.3182
# 	Sum:                   32285.8818
# 	Mean:                  32.3182
# 	Median:                32.3182
# 	StDev:                 0
# 	Most common values:    32.3182 (999x)
#
#   7. "Long_"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1
# 	Smallest value:        -86.9023
# 	Largest value:         -86.9023
# 	Sum:                   -86815.3977
# 	Mean:                  -86.9023
# 	Median:                -86.9023
# 	StDev:                 0
# 	Most common values:    -86.9023 (999x)
#
#   8. "Doses_alloc"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         11
# 	Smallest value:        0
# 	Largest value:         640150
# 	Sum:                   50096300
# 	Mean:                  246779.802956
# 	Median:                40950
# 	StDev:                 261263.273702
# 	Most common values:    None (796x)
# 	                       40950 (89x)
# 	                       640150 (32x)
# 	                       599200 (32x)
# 	                       0 (14x)
#
#   9. "Doses_shipped"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         230
# 	Smallest value:        0
# 	Largest value:         4783230
# 	Sum:                   911016480
# 	Mean:                  1436934.511041
# 	Median:                1170120
# 	StDev:                 1395483.047436
# 	Most common values:    None (365x)
# 	                       0 (155x)
# 	                       244000 (15x)
# 	                       993715 (12x)
# 	                       281100 (12x)
#
#  10. "Doses_admin"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         548
# 	Smallest value:        0
# 	Largest value:         3308961
# 	Sum:                   594716601
# 	Mean:                  635380.983974
# 	Median:                153924
# 	StDev:                 845047.553306
# 	Most common values:    0 (191x)
# 	                       None (63x)
# 	                       605280 (23x)
# 	                       668848 (23x)
# 	                       5181 (20x)
#
#  11. "Stage_One_Doses"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         288
# 	Smallest value:        5181
# 	Largest value:         1928903
# 	Sum:                   359256279
# 	Mean:                  786118.772429
# 	Median:                674810
# 	StDev:                 701348.406379
# 	Most common values:    None (542x)
# 	                       20354 (86x)
# 	                       5181 (20x)
# 	                       474065 (4x)
# 	                       378514 (2x)
#
#  12. "Stage_Two_Doses"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         322
# 	Smallest value:        42
# 	Largest value:         1462435
# 	Sum:                   232802584
# 	Mean:                  541401.35814
# 	Median:                553086.5
# 	StDev:                 397344.106161
# 	Most common values:    None (569x)
# 	                       591616 (6x)
# 	                       43 (6x)
# 	                       60 (5x)
# 	                       87 (5x)
#
#  13. "Combined_Key"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         11 characters
# 	Most common values:    Alabama, US (999x)
#
# Row count: 999

# %% [markdown]
# #### Collecting People Vaccinated Dataset

# %%
# !wget https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/us_data/time_series/people_vaccinated_us_timeline.csv
# Out:
# --2021-11-27 17:37:20--  https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/us_data/time_series/people_vaccinated_us_timeline.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1585905 (1.5M) [text/plain]
# Saving to: ‘people_vaccinated_us_timeline.csv’
#
# people_vaccinated_u 100%[===================>]   1.51M  --.-KB/s    in 0.01s
#
# 2021-11-27 17:37:20 (105 MB/s) - ‘people_vaccinated_us_timeline.csv’ saved [1585905/1585905]

# %%
# !mv people_vaccinated_us_timeline.csv people_vaccinated.csv # changing the name of the orginal downloaded csv file into people_vaccinated.csv

# %%
# !wc -l people_vaccinated.csv # printing the number of lines presents in the people_vaccinated.csv file
# Out:
# 21433 people_vaccinated.csv

# %%
# !head people_vaccinated.csv | csvcut -n # printing the first 10 lines of the people_vaccinated.csv file
# Out:
#   1: FIPS
#   2: Province_State
#   3: Country_Region
#   4: Date
#   5: Lat
#   6: Long_
#   7: Combined_Key
#   8: People_Fully_Vaccinated
#   9: People_Partially_Vaccinated

# %%
# !head -5 people_vaccinated.csv | csvlook # rendering the people_vaccinated.csv file into a readable format
# Out:
# | FIPS | Province_State | Country_Region |       Date |     Lat |    Long_ | Combined_Key | People_Fully_Vaccinated | People_Partially_Vaccinated |
# | ---- | -------------- | -------------- | ---------- | ------- | -------- | ------------ | ----------------------- | --------------------------- |
# | True | Alabama        | US             | 2020-12-10 | 32.318… | -86.902… | Alabama, US  |                         |                             |
# | True | Alabama        | US             | 2020-12-11 | 32.318… | -86.902… | Alabama, US  |                         |                             |
# | True | Alabama        | US             | 2020-12-12 | 32.318… | -86.902… | Alabama, US  |                         |                             |
# | True | Alabama        | US             | 2020-12-13 | 32.318… | -86.902… | Alabama, US  |                         |                             |

# %%
# !head -n 1000 vaccine.csv | csvstat # printing the descriptive statistics for the first 1000 lines of the people_vaccinated.csv file
# Out:
#   1. "Province_State"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         7 characters
# 	Most common values:    Alabama (999x)
#
#   2. "Date"
#
# 	Type of data:          Date
# 	Contains null values:  False
# 	Unique values:         198
# 	Smallest value:        2020-12-10
# 	Largest value:         2021-06-25
# 	Most common values:    2021-03-15 (6x)
# 	                       2021-03-16 (6x)
# 	                       2021-03-17 (6x)
# 	                       2021-03-18 (6x)
# 	                       2021-03-19 (6x)
#
#   3. "Vaccine_Type"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         6
# 	Longest value:         10 characters
# 	Most common values:    All (198x)
# 	                       Moderna (198x)
# 	                       Pfizer (198x)
# 	                       Unassigned (194x)
# 	                       Janssen (109x)
#
#   4. "FIPS"
#
# 	Type of data:          Boolean
# 	Contains null values:  False
# 	Unique values:         1
# 	Most common values:    True (999x)
#
#   5. "Country_Region"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         2 characters
# 	Most common values:    US (999x)
#
#   6. "Lat"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1
# 	Smallest value:        32.3182
# 	Largest value:         32.3182
# 	Sum:                   32285.8818
# 	Mean:                  32.3182
# 	Median:                32.3182
# 	StDev:                 0
# 	Most common values:    32.3182 (999x)
#
#   7. "Long_"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1
# 	Smallest value:        -86.9023
# 	Largest value:         -86.9023
# 	Sum:                   -86815.3977
# 	Mean:                  -86.9023
# 	Median:                -86.9023
# 	StDev:                 0
# 	Most common values:    -86.9023 (999x)
#
#   8. "Doses_alloc"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         11
# 	Smallest value:        0
# 	Largest value:         640150
# 	Sum:                   50096300
# 	Mean:                  246779.802956
# 	Median:                40950
# 	StDev:                 261263.273702
# 	Most common values:    None (796x)
# 	                       40950 (89x)
# 	                       640150 (32x)
# 	                       599200 (32x)
# 	                       0 (14x)
#
#   9. "Doses_shipped"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         230
# 	Smallest value:        0
# 	Largest value:         4783230
# 	Sum:                   911016480
# 	Mean:                  1436934.511041
# 	Median:                1170120
# 	StDev:                 1395483.047436
# 	Most common values:    None (365x)
# 	                       0 (155x)
# 	                       244000 (15x)
# 	                       993715 (12x)
# 	                       281100 (12x)
#
#  10. "Doses_admin"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         548
# 	Smallest value:        0
# 	Largest value:         3308961
# 	Sum:                   594716601
# 	Mean:                  635380.983974
# 	Median:                153924
# 	StDev:                 845047.553306
# 	Most common values:    0 (191x)
# 	                       None (63x)
# 	                       605280 (23x)
# 	                       668848 (23x)
# 	                       5181 (20x)
#
#  11. "Stage_One_Doses"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         288
# 	Smallest value:        5181
# 	Largest value:         1928903
# 	Sum:                   359256279
# 	Mean:                  786118.772429
# 	Median:                674810
# 	StDev:                 701348.406379
# 	Most common values:    None (542x)
# 	                       20354 (86x)
# 	                       5181 (20x)
# 	                       474065 (4x)
# 	                       378514 (2x)
#
#  12. "Stage_Two_Doses"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         322
# 	Smallest value:        42
# 	Largest value:         1462435
# 	Sum:                   232802584
# 	Mean:                  541401.35814
# 	Median:                553086.5
# 	StDev:                 397344.106161
# 	Most common values:    None (569x)
# 	                       591616 (6x)
# 	                       43 (6x)
# 	                       60 (5x)
# 	                       87 (5x)
#
#  13. "Combined_Key"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1
# 	Longest value:         11 characters
# 	Most common values:    Alabama, US (999x)
#
# Row count: 999

# %% [markdown]
# #### Collecting Testing Dataset

# %%
# !wget https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/testing_data/time_series_covid19_US.csv
# Out:
# --2021-11-27 17:37:37--  https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/testing_data/time_series_covid19_US.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2271759 (2.2M) [text/plain]
# Saving to: ‘time_series_covid19_US.csv’
#
# time_series_covid19 100%[===================>]   2.17M  --.-KB/s    in 0.02s
#
# 2021-11-27 17:37:37 (89.5 MB/s) - ‘time_series_covid19_US.csv’ saved [2271759/2271759]

# %%
# !mv time_series_covid19_US.csv testing.csv # changing the name of the orginal downloaded csv file into testing.csv

# %%
# !wc -l testing.csv # printing the number of lines presents in the testing.csv file
# Out:
# 35565 testing.csv

# %%
# !head testing.csv | csvcut -n # printing the first 10 lines of the testing.csv file
# Out:
#   1: date
#   2: state
#   3: cases_conf_probable
#   4: cases_confirmed
#   5: cases_probable
#   6: tests_viral_positive
#   7: tests_viral_negative
#   8: tests_viral_total
#   9: tests_antigen_positive
#  10: tests_antigen_total
#  11: people_viral_positive
#  12: people_viral_total
#  13: people_antigen_positive
#  14: people_antigen_total
#  15: encounters_viral_total
#  16: tests_combined_total

# %%
# !head -5 testing.csv | csvlook # rendering the testing.csv file into a readable format
# Out:
# |       date | state | cases_conf_probable | cases_confirmed | cases_probable | tests_viral_positive | tests_viral_negative | tests_viral_total | tests_antigen_positive | tests_antigen_total | people_viral_positive | people_viral_total | people_antigen_positive | people_antigen_total | encounters_viral_total | tests_combined_total |
# | ---------- | ----- | ------------------- | --------------- | -------------- | -------------------- | -------------------- | ----------------- | ---------------------- | ------------------- | --------------------- | ------------------ | ----------------------- | -------------------- | ---------------------- | -------------------- |
# | 2020-03-06 | AK    |                     |                 |                |                      |                      |                 8 |                        |                     |                       |                    |                         |                      |                        |                    8 |
# | 2020-03-07 | AK    |                     |                 |                |                      |                      |                12 |                        |                     |                       |                    |                         |                      |                        |                   12 |
# | 2020-03-08 | AK    |                     |                 |                |                      |                      |                14 |                        |                     |                       |                    |                         |                      |                        |                   14 |
# | 2020-03-09 | AK    |                     |                 |                |                      |                      |                23 |                        |                     |                       |                    |                         |                      |                        |                   23 |

# %%
# !head -n 1000 testing.csv | csvstat # printing the descriptive statistics for the first 1000 lines of the testing.csv file
# Out:
#   1. "date"
#
# 	Type of data:          Date
# 	Contains null values:  False
# 	Unique values:         600
# 	Smallest value:        2020-03-06
# 	Largest value:         2021-10-26
# 	Most common values:    2020-03-07 (2x)
# 	                       2020-03-08 (2x)
# 	                       2020-03-09 (2x)
# 	                       2020-03-10 (2x)
# 	                       2020-03-11 (2x)
#
#   2. "state"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         2
# 	Longest value:         2 characters
# 	Most common values:    AK (600x)
# 	                       AL (399x)
#
#   3. "cases_conf_probable"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         872
# 	Smallest value:        0
# 	Largest value:         518234
# 	Sum:                   103854382
# 	Mean:                  105115.771255
# 	Median:                60399
# 	StDev:                 140925.470189
# 	Most common values:    None (11x)
# 	                       0 (6x)
# 	                       71035 (5x)
# 	                       71384 (5x)
# 	                       90642 (5x)
#
#   4. "cases_confirmed"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         123
# 	Smallest value:        64782
# 	Largest value:         403401
# 	Sum:                   17175147
# 	Mean:                  85025.480198
# 	Median:                72669.5
# 	StDev:                 29944.260285
# 	Most common values:    None (797x)
# 	                       71035 (5x)
# 	                       71384 (5x)
# 	                       90642 (5x)
# 	                       70208 (4x)
#
#   5. "cases_probable"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         3
# 	Smallest value:        0
# 	Largest value:         114833
# 	Sum:                   114833
# 	Mean:                  568.480198
# 	Median:                0
# 	StDev:                 8079.621685
# 	Most common values:    None (797x)
# 	                       0 (201x)
# 	                       114833 (1x)
#
#   6. "tests_viral_positive"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         337
# 	Smallest value:        4024
# 	Largest value:         154360
# 	Sum:                   28691569
# 	Mean:                  64186.955257
# 	Median:                70406
# 	StDev:                 37747.298055
# 	Most common values:    None (552x)
# 	                       81975 (5x)
# 	                       104923 (5x)
# 	                       130784 (5x)
# 	                       65613 (4x)
#
#   7. "tests_viral_negative"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         339
# 	Smallest value:        253987
# 	Largest value:         3128936
# 	Sum:                   735479362
# 	Mean:                  1645367.700224
# 	Median:                1739746
# 	StDev:                 837402.637648
# 	Most common values:    None (552x)
# 	                       2297458 (5x)
# 	                       2664548 (5x)
# 	                       1517076 (4x)
# 	                       1799056 (4x)
#
#   8. "tests_viral_total"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         881
# 	Smallest value:        8
# 	Largest value:         4337300
# 	Sum:                   1531248511
# 	Mean:                  1532781.292292
# 	Median:                1457053
# 	StDev:                 1259038.377999
# 	Most common values:    2382952 (5x)
# 	                       2773181 (5x)
# 	                       1584548 (4x)
# 	                       1873407 (4x)
# 	                       2262583 (4x)
#
#   9. "tests_antigen_positive"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  10. "tests_antigen_total"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  11. "people_viral_positive"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         871
# 	Smallest value:        0
# 	Largest value:         403401
# 	Sum:                   89803393
# 	Mean:                  90894.12247
# 	Median:                60207
# 	StDev:                 110592.904189
# 	Most common values:    None (11x)
# 	                       0 (6x)
# 	                       71035 (5x)
# 	                       71384 (5x)
# 	                       90642 (5x)
#
#  12. "people_viral_total"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  13. "people_antigen_positive"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  14. "people_antigen_total"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  15. "encounters_viral_total"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (999x)
#
#  16. "tests_combined_total"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         881
# 	Smallest value:        8
# 	Largest value:         4337300
# 	Sum:                   1531248511
# 	Mean:                  1532781.292292
# 	Median:                1457053
# 	StDev:                 1259038.377999
# 	Most common values:    2382952 (5x)
# 	                       2773181 (5x)
# 	                       1584548 (4x)
# 	                       1873407 (4x)
# 	                       2262583 (4x)
#
# Row count: 999

# %% [markdown]
# ## Ask 2 - Surveying and Wrangling Data (15%)
#
# Acquire the data, survey it and wrangle it to suitable format. You may use one or more of the following methods for acquiring and wrangling the data:
# - Unix command line tools (e.g. csvkit)
# - Relational databases
# - Spark
# - You may also use wrangling tool (e.g. Trifacta)
#
# Describe any concerns with the data and changes you expect to overcome.
#
# Expectations: document your findings in the code. Make sure you describe each step in a complete and concise manner.

# %% [markdown]
# ## Ask 3 - Attestation (-10% for non-compliance)
#
# All project team members must contribute meaningfully to the project and have complete knowledge on any part of it.
#
# Each group member MUST attest to his/her individual contributions in coding, and presentation write up.
#
# Penalty: -10% for non-compliance

# %% [markdown]
# ## Ask 4 - Analytical Questions (15%)
#
# Communicate among your group members and produce analytical questions you want to answer with the data. Minimum of 4 major questions are required.
#
# You may consider me as your Sponsor. Arrange a 30 min meeting with me to discuss this part, if necessary.
#
# Expectation: A list of analytical questions that your model can answer. Check https://coronavirus.jhu.edu
# - ”tracking” -> “Critical Trends” or U.S. Map
# - “Vaccines” -> “Tracker” for ideas

# %% [markdown]
# ## Ask 5 - Designing a Dimensional Database (25%)
#
# Design a dimensional database to cover “Cases and Deaths”, “Vaccinations” and “Testing” datasets (Daily and for U.S.). I expect that your design will allow all other groups to answer most of their questions.
#
# Be precise and document your design correctly.
#
# Expectation: A star schema diagram detailing the design. Would be nice to produce an image of the design and added it to your code.

# %% [markdown]
# ## Ask 6 - Writing Queries for Analytical Questions (35%)
#
# Write queries to answer your analytical questions.
#
# Produce charts and make sure to include your code or a copy of chart (if you use outside Jupyter notebook tools).
#
# You are free to use any tool for visualization (e.g. tableau, ggplot, matplotlib,..).
#
# Expectation: set of queries, results and charts. Those should be compatible with your presentation.
