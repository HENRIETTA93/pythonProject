# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## demo
X=np.empty((100,2))
Y=np.empty((100,2))
X[:,0]=np.random.uniform(0.,100., size=100)
X[:,1]=0.75*X[:,0]+3.+np.random.normal(0,10., size=100)
Y[:,1]=0.25*X[:,0]+4.+np.random.normal(0,10., size=100)
X[:,0]
# Out:
# array([60.10947095,  9.9034822 ,  5.31699696, 11.12065741, 54.25427871,
#        29.339656  , 65.29358428, 76.33622677, 78.68716315, 96.65033193,
#        87.64278714, 93.5371173 , 15.2061347 , 71.99035731, 87.31492255,
#        20.51970118, 72.56960904, 35.04340252, 74.66869106, 90.33957461,
#        51.66572526, 17.76673534, 22.32375517, 26.64136117, 98.45240718,
#        37.72341961, 50.01353924, 83.78579741,  0.42332878, 75.80430166,
#        46.47734908, 20.92570562, 75.73854589, 97.94506829, 16.34749232,
#        31.71084987, 76.17956959, 38.2352272 ,  1.51285157, 32.9064026 ,
#         8.32832702, 91.43500832, 21.45021733, 11.7691054 , 93.3296335 ,
#        53.61836551, 19.92953619, 43.36557889, 31.63265887, 71.29700483,
#        66.73834105, 62.54440046, 33.22294462, 41.86019739, 88.08564617,
#        15.50072403, 91.0173512 , 67.79086709, 50.15029301, 25.85734836,
#        24.56338545, 72.69051145, 92.73322884, 67.33306714, 98.32197962,
#        35.60909329, 95.97028593,  4.96456138,  5.51258413, 46.78616952,
#        28.60517304, 71.62005244, 34.47256629, 10.63007719, 59.84063337,
#        11.42861117, 50.51964603, 66.03463802, 54.49117146, 82.05854384,
#        68.93834417, 71.00246114, 82.90282015, 82.9134975 , 17.58834065,
#        77.34576102, 97.49668407, 75.42814082, 79.98827407, 93.7323827 ,
#        84.34071425, 54.04405365, 44.9957323 , 89.99117227, 48.06883394,
#         9.68306476, 42.59249993,  5.9330568 , 92.37660422, 55.96603845])

# %%
plt.scatter(X[:,1], Y[:,1])
plt.show()

# %%
plt.scatter(X[:,0],Y[:,1])
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c',s='d' ,data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
plt.scatter('a', 'b', data=data)

# %%
plt.scatter('c', 'd', data=data)
